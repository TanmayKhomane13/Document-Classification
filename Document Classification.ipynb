# %% [markdown]
# # Importing Libraries

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torchtext.data.utils import get_tokenizer
from torchtext.datasets import AG_NEWS
from torchtext.vocab import build_vocab_from_iterator
from torch.utils.data.dataset import random_split
from torchtext.data.functional import to_map_style_dataset
from sklearn.model_selection import train_test_split
from IPython.display import Markdown as md

# %% [markdown]
# ### Import Dataset

# %%
import os
os.makedirs(".data", exist_ok = True)

train_iter = iter(AG_NEWS(split = "train"))

# %% [markdown]
# ### Class Labels

# %%
ag_news_label = {1: "World", 2: "Sports", 3: "Business", 4: "Sci/Tech"}

# %%
num_class = len(set([label for (label, text) in train_iter]))
num_class
# Out:
# 4

# %% [markdown]
# # Creating Tokens

# %%
train_iter = AG_NEWS(split = "train")

# %%
tokenizer = get_tokenizer("basic_english")

# %%
def yield_tokens(data_iter):
    for _, text in data_iter:
        yield tokenizer(text.lower())

# %%
vocab = build_vocab_from_iterator(yield_tokens(train_iter), specials = ["<unk>"])
vocab.set_default_index(vocab["<unk>"])

# %%
print(f"Vocabulary Size: {len(vocab)}")
print(f"Sample Tokens: {list(vocab.get_stoi().keys())[:-1]}")
# Out:
# Vocabulary Size: 95811
# Sample Tokens: ['zyprexa', 'zwiki', 'zurab', 'zuhua', 'zubrin', 'zovko', 'zotinca', 'zos', 'zoology', 'zoner', 'zoll', 'zolecki', 'zogby\\\\&lt', 'zoch', 'zocalo', 'znamenskoye', 'zits', 'zimbabwe*s', 'zilch', 'zih-droo', 'zig-zags', 'zig', 'zif', 'zhukov\\said', 'zhiguli', 'zherdev', 'zest', 'zeros', 'zero-day', 'zennstrm', 'zenati', 'zen-like', 'zeitoun', 'zeitgeist', 'zealand\\\\yahoo', 'zawodny', 'zavos', 'zauchensee', 'zapped', 'zap\\space', 'zanganeh', 'zane', 'zalpa', 'zalm\\says', 'zaki', 'zakeli', 'zakaev', 'zainab', 'zahniser', 'zafi-b', 'zafarullah', 'zaat', 'zaandam', 'za/sections/business/2004/0409231157', 'z/os', 'z-5500', 'yzr-m1', 'yussuf', 'yunessi', 'yukoss', 'yukiko', 'yuichi', 'yudhyono', 'yudhoyono\\has', 'yudel', 'yuck', 'yuba', 'yrok', 'yrk', 'yr-toshiba', 'yoyong', 'yoy', 'yourdon', 'your\\primary', 'your\\own', 'young\\consumers', 'young-adult', 'you\\often', 'you\\can', 'you\\\\after', 'you\\', 'yoshioka', 'yoshikazu', 'yorkwal-mart', 'yorkon', 'yorkhitachi', 'yorkcurt', 'york\\city', 'york\\and', 'york/new', 'york/houston', 'york/hong', 'york-the', 'yoof', 'yolk', 'yogurts', 'ymcas', 'yle', 'yiorgos', 'yield-slashing', 'yew', 'yet-to-open', 'yeste', 'yer', 'yep', 'yeo', 'yen\\put', 'yen\\programmer', 'yemenidjian', 'yemeni\\national', 'yelp', 'yeh', 'yediot', 'yearshuman', 'years\\old', 'years\\for', 'years-old', 'years--how', 'yearin', 'year\\without', 'year\\launched', 'year\\end', 'year\\ago', 'year-to-june', 'year-round', 'year-plus', 'year-olds', 'year-ending', 'year-earlier\\loss', 'year-', 'ydstie', 'yawned', 'yasuhiro', 'yastrzemski', 'yassin-style', 'yashwanthpur', 'yashin', 'yartsev', 'yarmuk', 'yap', 'yankees-twins', 'yankeeland', 'yangons', 'yana', 'yamamah', 'yamagata', 'yai', 'yahoo\\\\google', 'yacoub', 'yachtswoman', 'xxxiv', 'xx', 'xwall', 'xtra', 'xtensions', 'xprize', 'xml/rss', 'xml-based', 'xinsheng', 'xinhuanetby', 'xinhuanet-', 'xinhua\\news', 'xingsheng', 'xilutian', 'xiaochun', 'xianyan', 'xiamen', 'xhtml', 'xga', 'xforms', 'xeroxinstitution', 'xeon-processor', 'xeon-based', 'xenpak-based', 'xenon', 'xdms', 'xcor', 'xclef', 'xaml', 'x\\v10', 'x300', 'x10', 'x-denotes', 'x-boxes', 'x-box', 'wyclef', 'wwmd', 'wus', 'wurster', 'wunsiedel', 'wuling', 'wuertz', 'wu-tang', 'wtop', 'wto-incompatible', 'wtn', 'wti', 'wtf', 'wtas', 'wss2003', 'wsb', 'wrt', 'wronged', 'wrm', 'writings', 'wristbands', 'wright-patterson', 'wrests', 'wrestling-boxing', 'wrestle-o', 'wrbb-fm', 'wrapup-1-milan', 'wqam', 'wpp\\', 'wpp-grey', 'wpni', 'wove', 'wounding\\four', 'wounded\\when', 'wounded\\65', 'would\\you', 'would\\squeeze', 'would\\require', 'x-rated', 'would\\report', 'would\\make', 'would\\fuel', 'would\\enable', 'would\\double', 'worst\\crisis', 'worse-shooting', 'worry\\about', 'worries\\made', 'worried\\about', 'wormwood', 'worm_zafi', 'worm-style', 'worm-based', 'worlwide', 'worldwide_', 'worldly-wise', 'worldcom\\bankruptcy', 'world\\body', 'world\\', 'world-like', 'world-leading', 'world-championship', 'workspaces', 'works-in-progress', 'work\\and', 'work-visa', 'work-rule', 'wordsmith', 'woot', 'woosie', 'wooping', 'wooo', 'woonboot', 'wooly', 'woolworths-led', 'woolworth', 'woofing', 'woods\\is', 'woodhaven', 'woodcock', 'wood-paneled', 'wood-panel', 'wood&lt', 'wonkette', 'wonka', 'wonderment', 'wonderfully', 'won25', 'womenswear', 'women-only', 'womans', 'wollensky', 'wolfson', 'wolfpacks', 'wolfed', 'wolf-control', 'wohl', 'wobbler', 'wnav-1430', 'wltpctpfpanew', 'wlodzimierz', 'wlll', 'wk', 'wjz/ap', 'wjz-13', 'wjib-am', 'wjib', 'wittenauer', 'withthe', 'withraws', 'without\\leaving', 'within\\three', 'within--chief', 'withering\\accusations', 'withered', 'withdraw\\from', 'withdisloyalty', 'with\\refineries', 'with\\programming', 'with\\police', 'with\\oracle', 'with\\last', 'with\\jewel-encrusted', 'with\\jaundice', 'with\\iran', 'with\\internet', 'with\\high-speed', 'with\\faster', 'with\\extinction', 'with\\driving', 'with\\delivery', 'with\\consumer', 'with\\bases', 'with\\ac ...
